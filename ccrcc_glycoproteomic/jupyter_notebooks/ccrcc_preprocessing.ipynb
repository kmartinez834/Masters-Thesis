# %%
import pandas as pd
import numpy as np

# %%
# Import the data

orig_df = pd.read_csv('../data/ccRCC_TMT_intact glycopeptide_abundance_MD-MAD_50percentQuant_imputed.tsv', sep="\t")
df = orig_df.copy(deep=True)
df
# Out:
#                                                    Index  CPT0079430001  \
# 0      LAMA5_222_IVPLENGEIVVSLVNGRPGAMnFSYSPLLR_251_2...      15.414611
# 1              ITIH2_113_GAFISnFSMTVDGK_126_6_N4H5F0S1G0      17.194097
# 2            APMAP_196_nMSFVNDLTVTQDGRK_211_1_N2H8F0S0G0      16.141039
# 3              FN1_535_HEEGHMLnCTCFGQGR_550_8_N4H5F0S1G0      14.363901
# 4             CD109_286_InGSANFSFNDEEMK_300_2_N2H8F0S0G0      16.823150
# ...                                                  ...            ...
# 10810  LAMA5_3244_LLLGGLPESGTIYnFSGCISNVFVQR_3269_14_...      14.867106
# 10811    CDH6_394_EDAQInTTIGSVTAQDPDAAR_414_6_N5H5F2S0G0      16.117845
# 10812         STAB1_1726_RnVTAAAQGFGYK_1738_2_N2H8F0S0G0      14.476855
# 10813       TFRC_242_DFEDLYTPVnGSIVIVR_258_10_N5H5F1S2G0      13.869988
# 10814          LGALS3BP_64_ALGFEnATQALGR_76_6_N4H5F0S2G0      15.641613
#
#        CPT0023360001  CPT0023350003  CPT0079410003  CPT0087040003  \
# 0          15.141840      15.609682      15.471691      15.715771
# 1          17.161645      17.531468      17.326459      18.490422
# 2          16.457631      17.102947      16.635474      16.398802
# 3          14.414845      14.800264      14.500603      15.219195
# 4          16.708205      18.149726      17.325074      16.910034
# ...              ...            ...            ...            ...
# 10810      14.887579      14.392180      15.014174      14.883073
# 10811      16.258365      15.445131      15.494352      15.729901
# 10812      14.707436      16.038721      17.058441      15.136480
# 10813      13.973556      13.995085      15.707804      14.661459
# 10814      15.549608      15.860276      16.001312      16.076735
#
#        CPT0077310003  CPT0077320001  CPT0087050003     NCI7.1  ...  \
# 0          15.582075      15.496776      14.825282  15.022257  ...
# 1          18.263531      17.662532      18.011022  17.697802  ...
# 2          16.089844      15.935161      16.072948  17.145775  ...
# 3          13.421427      14.927323      15.154007  13.987806  ...
# 4          16.288521      16.254138      16.395630  17.582609  ...
# ...              ...            ...            ...        ...  ...
# 10810      14.063906      15.361909      14.435584  14.405460  ...
# 10811      15.625359      15.808577      16.376311  15.900981  ...
# 10812      15.616709      15.878005      14.399267  13.821142  ...
# 10813      14.855362      14.525548      14.376457  14.922653  ...
# 10814      16.083150      15.888510      15.628290  15.816233  ...
#
#        CPT0012080003  CPT0021240003  CPT0009020003  CPT0017450001  \
# 0          16.304602      15.577816      15.480282      15.416095
# 1          17.662301      18.298394      17.844644      17.311183
# 2          15.999110      16.292136      15.647002      16.025746
# 3          14.666703      13.947380      14.735971      14.410160
# 4          17.729779      17.842208      16.695780      16.955491
# ...              ...            ...            ...            ...
# 10810      15.041097      14.735240      15.131692      15.048282
# 10811      14.154636      15.189448      15.689619      16.322294
# 10812      16.551848      16.819558      14.530854      15.712289
# 10813      14.519178      14.642389      13.999922      13.090964
# 10814      15.546039      16.328455      15.749899      16.282639
#
#        CPT0009060003  CPT0012900004  CPT0017410003  CPT0009080003  \
# 0          16.211603      16.095162      15.604792      15.304437
# 1          17.954562      18.296734      17.712529      17.892701
# 2          16.001401      15.964142      15.843208      15.250424
# 3          14.935134      14.425399      14.641417      15.268693
# 4          16.855874      17.198116      17.100007      17.133722
# ...              ...            ...            ...            ...
# 10810      14.876406      14.897740      15.353862      15.692505
# 10811      15.053775      15.759281      15.329724      15.718774
# 10812      15.552114      15.647152      16.139644      14.379797
# 10813      14.180602      14.429359      13.847798      13.688188
# 10814      16.364148      17.212025      16.490557      16.246464
#
#        CPT0012920003  CPT0009000003
# 0          15.366103      16.198534
# 1          17.804011      17.930018
# 2          15.183451      16.637151
# 3          14.903590      14.388618
# 4          16.997934      17.908736
# ...              ...            ...
# 10810      15.157848      15.196334
# 10811      15.322390      14.963758
# 10812      14.927656      15.504176
# 10813      13.806605      15.663297
# 10814      16.361678      15.792976
#
# [10815 rows x 197 columns]

# %%
# Transpose the dataframe, reset headers and index

df_T = df.T
df_T.columns = df_T.iloc[0]
df_T = df_T[1:]

df_T.reset_index(inplace=True)
df_T
# Out:
# Index          index  \
# 0      CPT0079430001
# 1      CPT0023360001
# 2      CPT0023350003
# 3      CPT0079410003
# 4      CPT0087040003
# ..               ...
# 191    CPT0012900004
# 192    CPT0017410003
# 193    CPT0009080003
# 194    CPT0012920003
# 195    CPT0009000003
#
# Index LAMA5_222_IVPLENGEIVVSLVNGRPGAMnFSYSPLLR_251_22_N4H5F1S0G0  \
# 0                                              15.414611
# 1                                               15.14184
# 2                                              15.609682
# 3                                              15.471691
# 4                                              15.715771
# ..                                                   ...
# 191                                            16.095162
# 192                                            15.604792
# 193                                            15.304437
# 194                                            15.366103
# 195                                            16.198534
#
# Index ITIH2_113_GAFISnFSMTVDGK_126_6_N4H5F0S1G0  \
# 0                                     17.194097
# 1                                     17.161645
# 2                                     17.531468
# 3                                     17.326459
# 4                                     18.490422
# ..                                          ...
# 191                                   18.296734
# 192                                   17.712529
# 193                                   17.892701
# 194                                   17.804011
# 195                                   17.930018
#
# Index APMAP_196_nMSFVNDLTVTQDGRK_211_1_N2H8F0S0G0  \
# 0                                       16.141039
# 1                                       16.457631
# 2                                       17.102947
# 3                                       16.635474
# 4                                       16.398802
# ..                                            ...
# 191                                     15.964142
# 192                                     15.843208
# 193                                     15.250424
# 194                                     15.183451
# 195                                     16.637151
#
# Index FN1_535_HEEGHMLnCTCFGQGR_550_8_N4H5F0S1G0  \
# 0                                     14.363901
# 1                                     14.414845
# 2                                     14.800264
# 3                                     14.500603
# 4                                     15.219195
# ..                                          ...
# 191                                   14.425399
# 192                                   14.641417
# 193                                   15.268693
# 194                                    14.90359
# 195                                   14.388618
#
# Index CD109_286_InGSANFSFNDEEMK_300_2_N2H8F0S0G0  \
# 0                                       16.82315
# 1                                      16.708205
# 2                                      18.149726
# 3                                      17.325074
# 4                                      16.910034
# ..                                           ...
# 191                                    17.198116
# 192                                    17.100007
# 193                                    17.133722
# 194                                    16.997934
# 195                                    17.908736
#
# Index PLXNB2_1031_EAESLQPMTVVGTDYVFHnDTK_1052_19_N5H5F1S0G0  \
# 0                                              14.832855
# 1                                              14.883942
# 2                                              14.342608
# 3                                              14.425776
# 4                                              14.234945
# ..                                                   ...
# 191                                            15.357927
# 192                                             14.74174
# 193                                            14.606062
# 194                                            14.506861
# 195                                            14.512838
#
# Index CTSC_51_DVnCSVMGPQEK_62_3_N4H6F0S0G0  \
# 0                                 13.05617
# 1                                13.579303
# 2                                12.847752
# 3                                12.412877
# 4                                12.150975
# ..                                     ...
# 191                              11.403616
# 192                              11.287389
# 193                              14.117903
# 194                              12.813975
# 195                              11.543097
#
# Index FGB_375_YRGTAGNALMDGASQLMGEnR_395_20_N4H5F0S1G0  \
# 0                                           16.359029
# 1                                           15.945842
# 2                                            16.09394
# 3                                           16.231234
# 4                                           15.950968
# ..                                                ...
# 191                                         15.502065
# 192                                         15.585231
# 193                                         16.026908
# 194                                         16.103657
# 195                                         15.525015
#
# Index CLU_97_ELPGVCnETMMALWEECKPCLK_118_7_N4H5F0S2G0  ...  \
# 0                                          17.979474  ...
# 1                                          17.658734  ...
# 2                                          17.740037  ...
# 3                                          17.220815  ...
# 4                                          16.888709  ...
# ..                                               ...  ...
# 191                                        16.530029  ...
# 192                                        17.039707  ...
# 193                                        18.260688  ...
# 194                                        19.029638  ...
# 195                                        16.901983  ...
#
# Index BTD_340_NPVGLIGAEnATGETDPSHSK_360_10_N2H5F0S0G0  \
# 0                                           15.595219
# 1                                           15.522371
# 2                                            14.86381
# 3                                           14.813011
# 4                                           14.752897
# ..                                                ...
# 191                                         14.596866
# 192                                         14.751935
# 193                                         15.755052
# 194                                         15.179109
# 195                                         14.536615
#
# Index GNS_356_GPGIKPnQTSK_366_7_N2H5F0S0G0  \
# 0                                16.896178
# 1                                17.969214
# 2                                 15.89373
# 3                                17.535315
# 4                                15.085696
# ..                                     ...
# 191                              15.774534
# 192                              15.918554
# 193                              17.782899
# 194                              16.671021
# 195                              15.889964
#
# Index SERPINA1_64_QLAHQSnSTNIFFSPVSIATAFAMLSLGTK_93_7_N5H5F0S2G0  \
# 0                                                14.7729
# 1                                               14.03173
# 2                                              14.174981
# 3                                              14.475654
# 4                                              14.938215
# ..                                                   ...
# 191                                            15.081243
# 192                                            15.282739
# 193                                            14.774031
# 194                                            14.786574
# 195                                            14.528124
#
# Index OLFML3_169_IYVLDGTQnDTAFVFPR_185_9_N4H5F1S0G0  \
# 0                                          17.00951
# 1                                         17.223192
# 2                                         16.085713
# 3                                         16.276239
# 4                                         16.071357
# ..                                              ...
# 191                                        16.64235
# 192                                       16.357851
# 193                                       17.353575
# 194                                       17.049744
# 195                                       16.104109
#
# Index FGG_65_DLQSLEDILHQVEnK_79_14_N5H6F1S1G0  \
# 0                                    17.00063
# 1                                   15.992055
# 2                                   16.342642
# 3                                   16.769055
# 4                                    16.33028
# ..                                        ...
# 191                                 16.043253
# 192                                 16.263307
# 193                                 15.470574
# 194                                 15.761524
# 195                                 15.596775
#
# Index LAMA5_3244_LLLGGLPESGTIYnFSGCISNVFVQR_3269_14_N3H5F0S1G0  \
# 0                                              14.867106
# 1                                              14.887579
# 2                                               14.39218
# 3                                              15.014174
# 4                                              14.883073
# ..                                                   ...
# 191                                             14.89774
# 192                                            15.353862
# 193                                            15.692505
# 194                                            15.157848
# 195                                            15.196334
#
# Index CDH6_394_EDAQInTTIGSVTAQDPDAAR_414_6_N5H5F2S0G0  \
# 0                                           16.117845
# 1                                           16.258365
# 2                                           15.445131
# 3                                           15.494352
# 4                                           15.729901
# ..                                                ...
# 191                                         15.759281
# 192                                         15.329724
# 193                                         15.718774
# 194                                          15.32239
# 195                                         14.963758
#
# Index STAB1_1726_RnVTAAAQGFGYK_1738_2_N2H8F0S0G0  \
# 0                                      14.476855
# 1                                      14.707436
# 2                                      16.038721
# 3                                      17.058441
# 4                                       15.13648
# ..                                           ...
# 191                                    15.647152
# 192                                    16.139644
# 193                                    14.379797
# 194                                    14.927656
# 195                                    15.504176
#
# Index TFRC_242_DFEDLYTPVnGSIVIVR_258_10_N5H5F1S2G0  \
# 0                                        13.869988
# 1                                        13.973556
# 2                                        13.995085
# 3                                        15.707804
# 4                                        14.661459
# ..                                             ...
# 191                                      14.429359
# 192                                      13.847798
# 193                                      13.688188
# 194                                      13.806605
# 195                                      15.663297
#
# Index LGALS3BP_64_ALGFEnATQALGR_76_6_N4H5F0S2G0
# 0                                     15.641613
# 1                                     15.549608
# 2                                     15.860276
# 3                                     16.001312
# 4                                     16.076735
# ..                                          ...
# 191                                   17.212025
# 192                                   16.490557
# 193                                   16.246464
# 194                                   16.361678
# 195                                   15.792976
#
# [196 rows x 10816 columns]

# %%
# Import biospecimen data, replace blankspace values with NaN, set headers to lowercase

biospecimen = pd.read_csv('../data/PDC_study_biospecimen_09182023_104440.tsv', sep="\t")
biospecimen.replace(r'^\s*$', np.nan, regex=True, inplace=True)

biospecimen.columns = [col.lower() for col in list(biospecimen.columns)]
biospecimen[:3]
# Out:
#                              aliquot id aliquot submitter id  \
# 0  b64adca6-2053-11e9-b7f8-0a80fada099c        CPT0025170003
# 1  1cb3cb3d-2054-11e9-b7f8-0a80fada099c               NCI7-2
# 2  c8117eba-2053-11e9-b7f8-0a80fada099c        CPT0065820001
#
#                               sample id sample submitter id  \
# 0  b3d4c7a4-204c-11e9-b7f8-0a80fada099c        C3L-00766-01
# 1  fc86d5da-204d-11e9-b7f8-0a80fada099c              NCI7-2
# 2  c85b0efd-204c-11e9-b7f8-0a80fada099c        C3L-00814-02
#
#                                 case id case submitter id  \
# 0  d610d697-1fb8-11e9-b7f8-0a80fada099c         C3L-00766
# 1  00dc49de-1fba-11e9-b7f8-0a80fada099c            NCI7-2
# 2  e63a8d1a-1fb8-11e9-b7f8-0a80fada099c         C3L-00814
#
#                         project name          sample type  primary site  \
# 0  CPTAC3 Discovery and Confirmatory        Primary Tumor        Kidney
# 1  CPTAC3 Discovery and Confirmatory           Cell Lines  Not Reported
# 2  CPTAC3 Discovery and Confirmatory  Solid Tissue Normal        Kidney
#
#                       disease type  ... sample ordinal shortest dimension  \
# 0  Clear Cell Renal Cell Carcinoma  ...            NaN                NaN
# 1                            Other  ...            NaN                NaN
# 2  Clear Cell Renal Cell Carcinoma  ...            NaN                NaN
#
#    time between clamping and freezing  time between excision and freezing  \
# 0                                 NaN                                 9.0
# 1                                 NaN                                 NaN
# 2                                 NaN                                13.0
#
#    tissue collection type   tissue type  tumor code tumor code id  \
# 0                     NaN         Tumor         NaN           NaN
# 1                     NaN  Not Reported         NaN           NaN
# 2                     NaN        Normal         NaN           NaN
#
#   tumor descriptor                                  program name
# 0              NaN  Clinical Proteomic Tumor Analysis Consortium
# 1     Not Reported  Clinical Proteomic Tumor Analysis Consortium
# 2              NaN  Clinical Proteomic Tumor Analysis Consortium
#
# [3 rows x 44 columns]

# %%
# Import clinical data, replace blankspace values with NaN, set headers to lowercase

clinical = pd.read_csv('../data/PDC_study_clinical_09182023_105327.tsv', sep="\t")
clinical.replace(r'^\s*$', np.nan, regex=True, inplace=True)

clinical.columns = [col.lower() for col in list(clinical.columns)]
clinical[:3]
# Out:
#                                 case id cases submitter id  related entities  \
# 0  d610d697-1fb8-11e9-b7f8-0a80fada099c          C3L-00766               NaN
# 1  00dc49de-1fba-11e9-b7f8-0a80fada099c             NCI7-2               NaN
# 2  e63a8d1a-1fb8-11e9-b7f8-0a80fada099c          C3L-00814               NaN
#
#    annotation                  genomic and imaging data resource  \
# 0         NaN  GDC: https://portal.gdc.cancer.gov/cases/03222...
# 1         NaN                                                NaN
# 2         NaN  GDC: https://portal.gdc.cancer.gov/cases/e8bc3...
#
#                 ethnicity        gender          race    morphology  \
# 0  Not Hispanic or Latino        Female         White        8312/3
# 1            Not Reported  Not Reported  Not Reported  Not Reported
# 2            Not Reported          Male  Not Reported        8312/3
#
#            primary diagnosis  ... gleason patterns percent margin distance  \
# 0  Renal cell carcinoma, NOS  ...                      NaN             NaN
# 1               Not Reported  ...                      NaN             NaN
# 2  Renal cell carcinoma, NOS  ...                      NaN             NaN
#
#   margins involved site pregnant at diagnosis satellite nodule present  \
# 0                   NaN                   NaN                      NaN
# 1                   NaN                   NaN                      NaN
# 2                   NaN                   NaN                      NaN
#
#   sites of involvement tumor depth who cns grade who nte grade diagnosis uuid
# 0                  NaN         NaN           NaN           NaN            NaN
# 1                  NaN         NaN           NaN           NaN            NaN
# 2                  NaN         NaN           NaN           NaN            NaN
#
# [3 rows x 152 columns]

# %%
# Import clinical exposure data, replace blankspace values with NaN, set headers to lowercase

clinical_exposure = pd.read_csv('../data/PDC_study_clinical_exposure_09182023_105327.tsv', sep="\t")
clinical_exposure.replace(r'^\s*$', np.nan, regex=True, inplace=True)

clinical_exposure.columns = [col.lower() for col in list(clinical_exposure.columns)]
clinical_exposure[:3]
# Out:
#                                 case id case submitter id  \
# 0  d610d697-1fb8-11e9-b7f8-0a80fada099c         C3L-00766
# 1  e63a8d1a-1fb8-11e9-b7f8-0a80fada099c         C3L-00814
# 2  a4300f90-1fb9-11e9-b7f8-0a80fada099c         C3N-01200
#
#                             exposure id exposure submitter id  \
# 0  1a6eac47-2c37-11ec-b712-0a4e2186f121          C3L-00766-EX
# 1  1af86552-2c37-11ec-b712-0a4e2186f121          C3L-00814-EX
# 2  1e212588-2c37-11ec-b712-0a4e2186f121          C3N-01200-EX
#
#    alcohol days per week  alcohol drinks per day alcohol history  \
# 0                    NaN                     NaN    Not Reported
# 1                    NaN                     NaN    Not Reported
# 2                    NaN                     NaN              No
#
#       alcohol intensity  asbestos exposure  cigarettes per day  ...  \
# 0               Unknown                NaN                 NaN  ...
# 1               Unknown                NaN                 NaN  ...
# 2  Lifelong Non-Drinker                NaN                 NaN  ...
#
#    age at onset  alcohol type  exposure duration  exposure duration years  \
# 0           NaN           NaN                NaN                      NaN
# 1           NaN           NaN                NaN                      NaN
# 2           NaN           NaN                NaN                      NaN
#
#    exposure type  marijuana use per week  parent with radiation exposure  \
# 0            NaN                     NaN                             NaN
# 1            NaN                     NaN                             NaN
# 2            NaN                     NaN                             NaN
#
#    secondhand smoke as child  smokeless tobacco quit age  tobacco use per day
# 0                        NaN                         NaN                  NaN
# 1                        NaN                         NaN                  NaN
# 2                        NaN                         NaN                  NaN
#
# [3 rows x 33 columns]

# %%
# Import clinical follow up data, replace blankspace values with NaN, set headers to lowercase

clinical_followup = pd.read_csv('../data/PDC_study_clinical_followup_09182023_105327.tsv', sep="\t")
clinical_followup.replace(r'^\s*$', np.nan, regex=True, inplace=True)

clinical_followup.columns = [col.lower() for col in list(clinical_followup.columns)]
clinical_followup[:3]
# Out:
#                                 case id case submitter id  \
# 0  d610d697-1fb8-11e9-b7f8-0a80fada099c         C3L-00766
# 1  e63a8d1a-1fb8-11e9-b7f8-0a80fada099c         C3L-00814
# 2  b118086f-1fb8-11e9-b7f8-0a80fada099c         C3L-00026
#
#                            follow up id follow up submitter id  adverse event  \
# 0  84d5f2b3-6c8b-4cc5-a4f7-1e77fe95991a           C3L-00766-FL            NaN
# 1  c8445e88-63fa-460e-ac6f-68563169843c           C3L-00814-FL            NaN
# 2  525353f6-5414-4962-bb9a-beeb8ced2777           C3L-00026-FL            NaN
#
#    adverse event grade  aids risk factors  \
# 0                  NaN                NaN
# 1                  NaN                NaN
# 2                  NaN                NaN
#
#    barretts esophagus goblet cells present    bmi  body surface area  ...  \
# 0                                      NaN  68.59                NaN  ...
# 1                                      NaN  30.56                NaN  ...
# 2                                      NaN  28.23                NaN  ...
#
#    risk factor treatment  scan tracer used  undescended testis corrected  \
# 0                    NaN               NaN                           NaN
# 1                    NaN               NaN                           NaN
# 2                    NaN               NaN                           NaN
#
#   undescended testis corrected age  undescended testis corrected laterality  \
# 0                              NaN                                      NaN
# 1                              NaN                                      NaN
# 2                              NaN                                      NaN
#
#    undescended testis corrected method  undescended testis history  \
# 0                                  NaN                         NaN
# 1                                  NaN                         NaN
# 2                                  NaN                         NaN
#
#    undescended testis history laterality  viral hepatitis serologies  weight
# 0                                    NaN                         NaN  167.38
# 1                                    NaN                         NaN   96.62
# 2                                    NaN                         NaN   75.00
#
# [3 rows x 70 columns]

# %%
# After merging files, drop duplicate columns with identical values

def drop_dup_columns(df_name):
    dup_cols = [x for x in df_name.columns if "_y" in x]
    num_dropped = 0
    cols_dropped = []

    for col in dup_cols:
        left_col = col.split("_")[0]
        right_col = col
        # Check if columns contains all the same values
        if len(df_name[[left_col,right_col]][df_name[left_col] != df_name[right_col]].dropna(how='all')) == 0:
            df_name.drop(right_col, axis=1, inplace=True)
            num_dropped += 1
            cols_dropped.append(right_col)
        # Check if columns can be merged without changing any values other than NaN
        elif len(df_name[df_name[left_col].fillna(df_name[right_col]) != df_name[right_col].fillna(df_name[left_col])]) == 0:
            df_name[left_col] = df_name[left_col].fillna(df_name[right_col])
            df_name.drop(right_col, axis=1, inplace=True)
            num_dropped += 1
            cols_dropped.append(right_col)
        
    # Print list of columns that do not match    
    if len([x for x in df_name.columns if "_y" in x]) != 0:
        print("Columns do not match", [x for x in df_name.columns if "_y" in x])

    # Print number and list of columns dropped
    print (f"Dropped {num_dropped} duplicate columns")
    for col in cols_dropped:
        print (f"Dropped: {col}")

    return df_name

# %%
# Merge abundance and biospecimen dataframes

abundance_biospecimen = pd.merge(df_T,biospecimen, left_on="index", right_on="aliquot submitter id", validate="one_to_one", suffixes=(None, "_y"))
abundance_biospecimen.drop("index", axis=1, inplace=True)
abundance_biospecimen.shape
# Out:
# (191, 10859)

# %%
abundance_biospecimen = drop_dup_columns(abundance_biospecimen)
abundance_biospecimen.shape
# Out:
# Dropped 0 duplicate columns
# (191, 10859)

# %%
# Merge dataframe from previous step with clinical dataframe

abundance_biospecimen_clinical = abundance_biospecimen.merge(clinical, on="case id", validate="many_to_one", suffixes=(None, "_y"))
abundance_biospecimen_clinical.shape
# Out:
# (191, 11010)

# %%
abundance_biospecimen_clinical = drop_dup_columns(abundance_biospecimen_clinical)
abundance_biospecimen_clinical.shape
# Out:
# Dropped 4 duplicate columns
# Dropped: disease type_y
# Dropped: primary site_y
# Dropped: program name_y
# Dropped: project name_y
# (191, 11006)

# %%
# Merge dataframe from previous step with clinical exposure dataframe

abundance_biospecimen_clinical_exposure = abundance_biospecimen_clinical.merge(clinical_exposure, on="case id", validate= "many_to_one", suffixes=(None, "_y"))
abundance_biospecimen_clinical_exposure.shape
# Out:
# (183, 11038)

# %%
abundance_biospecimen_clinical_exposure = drop_dup_columns(abundance_biospecimen_clinical_exposure)
abundance_biospecimen_clinical_exposure.shape
# Out:
# Dropped 1 duplicate columns
# Dropped: case submitter id_y
# (183, 11037)

# %%
# Merge dataframe from previous step with clinical follow up dataframe

abundance_biospecimen_clinical_exposure_fu = abundance_biospecimen_clinical_exposure.merge(clinical_followup, on="case id", how="left", validate= "many_to_one", suffixes=(None, "_y"))
abundance_biospecimen_clinical_exposure_fu.shape
# Out:
# (183, 11106)

# %%
abundance_biospecimen_clinical_exposure_fu = drop_dup_columns(abundance_biospecimen_clinical_exposure_fu)
abundance_biospecimen_clinical_exposure_fu.shape
# Out:
# Columns do not match ['days to recurrence_y', 'progression or recurrence_y']
# Dropped 2 duplicate columns
# Dropped: case submitter id_y
# Dropped: hpv positive type_y
# (183, 11104)

# %%
# Review duplicate columns that could not be dropped or merged

final_df = abundance_biospecimen_clinical_exposure_fu.copy(deep=True)
final_df[final_df['days to recurrence'] != final_df['days to recurrence_y']][['days to recurrence','days to recurrence_y']].dropna(how='all')
# Out:
#     days to recurrence  days to recurrence_y
# 2                  NaN                 368.0
# 3                  NaN                 368.0
# 16                 NaN                 733.0
# 17                 NaN                 733.0
# 29                 NaN                 876.0
# 30                 NaN                 876.0
# 92                 NaN                 833.0
# 93                 NaN                 833.0
# 98                 NaN                 389.0
# 99                 NaN                 389.0
# 101                NaN                 456.0
# 102                NaN                 456.0
# 115                NaN                 779.0
# 116                NaN                 779.0
# 117                NaN                 594.0
# 118                NaN                 594.0
# 123                NaN                 780.0
# 124                NaN                 780.0
# 152            1416.00                1416.0

# %%
# Drop 'days to recurrence' as the only different rows are NaN

final_df.drop('days to recurrence', axis=1, inplace=True)
final_df.rename(columns={"days to recurrence_y": "days to recurrence"}, inplace=True)
final_df.shape
# Out:
# (183, 11103)

# %%
final_df[final_df['progression or recurrence_y'] != final_df['progression or recurrence']][['progression or recurrence','progression or recurrence_y']].dropna(how='any')
# Out:
#     progression or recurrence progression or recurrence_y
# 115                        No                         Yes
# 116                        No                         Yes

# %%
# Rename 'progression or recurrence_fu' as follow up resulted in a different value

final_df.rename(columns={"progression or recurrence_y": "progression or recurrence_fu"}, inplace=True)
final_df
# Out:
#     LAMA5_222_IVPLENGEIVVSLVNGRPGAMnFSYSPLLR_251_22_N4H5F1S0G0  \
# 0                                            15.414611
# 1                                            15.471691
# 2                                             15.14184
# 3                                            15.609682
# 4                                            15.715771
# ..                                                 ...
# 178                                          15.604792
# 179                                          16.211603
# 180                                          15.304437
# 181                                          16.095162
# 182                                          15.366103
#
#     ITIH2_113_GAFISnFSMTVDGK_126_6_N4H5F0S1G0  \
# 0                                   17.194097
# 1                                   17.326459
# 2                                   17.161645
# 3                                   17.531468
# 4                                   18.490422
# ..                                        ...
# 178                                 17.712529
# 179                                 17.954562
# 180                                 17.892701
# 181                                 18.296734
# 182                                 17.804011
#
#     APMAP_196_nMSFVNDLTVTQDGRK_211_1_N2H8F0S0G0  \
# 0                                     16.141039
# 1                                     16.635474
# 2                                     16.457631
# 3                                     17.102947
# 4                                     16.398802
# ..                                          ...
# 178                                   15.843208
# 179                                   16.001401
# 180                                   15.250424
# 181                                   15.964142
# 182                                   15.183451
#
#     FN1_535_HEEGHMLnCTCFGQGR_550_8_N4H5F0S1G0  \
# 0                                   14.363901
# 1                                   14.500603
# 2                                   14.414845
# 3                                   14.800264
# 4                                   15.219195
# ..                                        ...
# 178                                 14.641417
# 179                                 14.935134
# 180                                 15.268693
# 181                                 14.425399
# 182                                  14.90359
#
#     CD109_286_InGSANFSFNDEEMK_300_2_N2H8F0S0G0  \
# 0                                     16.82315
# 1                                    17.325074
# 2                                    16.708205
# 3                                    18.149726
# 4                                    16.910034
# ..                                         ...
# 178                                  17.100007
# 179                                  16.855874
# 180                                  17.133722
# 181                                  17.198116
# 182                                  16.997934
#
#     PLXNB2_1031_EAESLQPMTVVGTDYVFHnDTK_1052_19_N5H5F1S0G0  \
# 0                                            14.832855
# 1                                            14.425776
# 2                                            14.883942
# 3                                            14.342608
# 4                                            14.234945
# ..                                                 ...
# 178                                           14.74174
# 179                                          14.341116
# 180                                          14.606062
# 181                                          15.357927
# 182                                          14.506861
#
#     CTSC_51_DVnCSVMGPQEK_62_3_N4H6F0S0G0  \
# 0                               13.05617
# 1                              12.412877
# 2                              13.579303
# 3                              12.847752
# 4                              12.150975
# ..                                   ...
# 178                            11.287389
# 179                            11.059163
# 180                            14.117903
# 181                            11.403616
# 182                            12.813975
#
#     FGB_375_YRGTAGNALMDGASQLMGEnR_395_20_N4H5F0S1G0  \
# 0                                         16.359029
# 1                                         16.231234
# 2                                         15.945842
# 3                                          16.09394
# 4                                         15.950968
# ..                                              ...
# 178                                       15.585231
# 179                                       15.455444
# 180                                       16.026908
# 181                                       15.502065
# 182                                       16.103657
#
#     CLU_97_ELPGVCnETMMALWEECKPCLK_118_7_N4H5F0S2G0  \
# 0                                        17.979474
# 1                                        17.220815
# 2                                        17.658734
# 3                                        17.740037
# 4                                        16.888709
# ..                                             ...
# 178                                      17.039707
# 179                                      17.018237
# 180                                      18.260688
# 181                                      16.530029
# 182                                      19.029638
#
#     P4HA1_105_DMSDGFISnLTIQR_118_9_N2H6F0S0G0  ... risk factor treatment  \
# 0                                   16.248994  ...                   NaN
# 1                                   17.775143  ...                   NaN
# 2                                   16.499878  ...                   NaN
# 3                                   17.990332  ...                   NaN
# 4                                   17.698439  ...                   NaN
# ..                                        ...  ...                   ...
# 178                                 17.340122  ...                   NaN
# 179                                 17.432247  ...                   NaN
# 180                                 16.242812  ...                   NaN
# 181                                 17.593074  ...                   NaN
# 182                                 16.469135  ...                   NaN
#
#     scan tracer used undescended testis corrected  \
# 0                NaN                          NaN
# 1                NaN                          NaN
# 2                NaN                          NaN
# 3                NaN                          NaN
# 4                NaN                          NaN
# ..               ...                          ...
# 178              NaN                          NaN
# 179              NaN                          NaN
# 180              NaN                          NaN
# 181              NaN                          NaN
# 182              NaN                          NaN
#
#     undescended testis corrected age undescended testis corrected laterality  \
# 0                                NaN                                     NaN
# 1                                NaN                                     NaN
# 2                                NaN                                     NaN
# 3                                NaN                                     NaN
# 4                                NaN                                     NaN
# ..                               ...                                     ...
# 178                              NaN                                     NaN
# 179                              NaN                                     NaN
# 180                              NaN                                     NaN
# 181                              NaN                                     NaN
# 182                              NaN                                     NaN
#
#     undescended testis corrected method undescended testis history  \
# 0                                   NaN                        NaN
# 1                                   NaN                        NaN
# 2                                   NaN                        NaN
# 3                                   NaN                        NaN
# 4                                   NaN                        NaN
# ..                                  ...                        ...
# 178                                 NaN                        NaN
# 179                                 NaN                        NaN
# 180                                 NaN                        NaN
# 181                                 NaN                        NaN
# 182                                 NaN                        NaN
#
#     undescended testis history laterality viral hepatitis serologies weight
# 0                                     NaN                        NaN   80.0
# 1                                     NaN                        NaN   80.0
# 2                                     NaN                        NaN   94.0
# 3                                     NaN                        NaN   94.0
# 4                                     NaN                        NaN  128.0
# ..                                    ...                        ...    ...
# 178                                   NaN                        NaN    NaN
# 179                                   NaN                        NaN    NaN
# 180                                   NaN                        NaN    NaN
# 181                                   NaN                        NaN    NaN
# 182                                   NaN                        NaN    NaN
#
# [183 rows x 11103 columns]
