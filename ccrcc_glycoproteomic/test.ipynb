# %%
from ccrcc_preprocessing import preprocessed_data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from ccrcc_preprocessing import preprocessed_data
#
# ImportError: cannot import name 'preprocessed_data' from 'ccrcc_preprocessing' (c:\Users\karinamartinez\Box\Masters-Thesis\ccrcc_glycoproteomic\ccrcc_preprocessing.py)

# %%
df_T = df.T
df_T.columns = df_T.iloc[0]
df_T = df_T[1:].reset_index()
df_T
# Out:
# Index          index  ... LGALS3BP_64_ALGFEnATQALGR_76_6_N4H5F0S2G0
# 0      CPT0079430001  ...                                 15.641613
# 1      CPT0023360001  ...                                 15.549608
# 2      CPT0023350003  ...                                 15.860276
# 3      CPT0079410003  ...                                 16.001312
# 4      CPT0087040003  ...                                 16.076735
# ..               ...  ...                                       ...
# 191    CPT0012900004  ...                                 17.212025
# 192    CPT0017410003  ...                                 16.490557
# 193    CPT0009080003  ...                                 16.246464
# 194    CPT0012920003  ...                                 16.361678
# 195    CPT0009000003  ...                                 15.792976
#
# [196 rows x 10816 columns]
